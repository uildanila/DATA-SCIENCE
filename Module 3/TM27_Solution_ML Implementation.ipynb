# %% [markdown]
# `May 10, 2022`

# %% [markdown]
# ## **ML Implementation Exercise**

# %% [markdown]
# **Use hyundai dataset**
#
# - Explore the data, do EDA, modeling, and save model.
# - Try to predict new data with your saved model.

# %% [markdown]
# ### **Import libraries**

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn import metrics
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold

import category_encoders as ce
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor

from sklearn.preprocessing import StandardScaler, RobustScaler, PolynomialFeatures
from sklearn.preprocessing import PowerTransformer

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

import warnings
warnings.filterwarnings('ignore')

# pd.set_option('max_column', 100)

# %% [markdown]
# ### **Explore dataset**

# %%
df = pd.read_csv('hyundai.csv')
df
# Out:
#         model  year  price transmission  mileage fuelType  tax(£)   mpg  \
# 0         I20  2017   7999       Manual    17307   Petrol     145  58.9
# 1      Tucson  2016  14499    Automatic    25233   Diesel     235  43.5
# 2      Tucson  2016  11399       Manual    37877   Diesel      30  61.7
# 3         I10  2016   6499       Manual    23789   Petrol      20  60.1
# 4        IX35  2015  10199       Manual    33177   Diesel     160  51.4
# ...       ...   ...    ...          ...      ...      ...     ...   ...
# 4855      I30  2016   8680       Manual    25906   Diesel       0  78.4
# 4856      I40  2015   7830       Manual    59508   Diesel      30  65.7
# 4857      I10  2017   6830       Manual    13810   Petrol      20  60.1
# 4858   Tucson  2018  13994       Manual    23313   Petrol     145  44.8
# 4859   Tucson  2016  15999    Automatic    11472   Diesel     125  57.6
#
#       engineSize
# 0            1.2
# 1            2.0
# 2            1.7
# 3            1.0
# 4            2.0
# ...          ...
# 4855         1.6
# 4856         1.7
# 4857         1.0
# 4858         1.6
# 4859         1.7
#
# [4860 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4860 entries, 0 to 4859
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         4860 non-null   object
#  1   year          4860 non-null   int64
#  2   price         4860 non-null   int64
#  3   transmission  4860 non-null   object
#  4   mileage       4860 non-null   int64
#  5   fuelType      4860 non-null   object
#  6   tax(£)        4860 non-null   int64
#  7   mpg           4860 non-null   float64
#  8   engineSize    4860 non-null   float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 341.8+ KB

# %%
# Rename the tax(£) column 
df.rename(columns={'tax(£)': 'tax'}, inplace=True)

# %%
# print a summary of the numerical Hyundai used car data
df.describe()
# Out:
#               year        price        mileage          tax          mpg  \
# count  4860.000000   4860.00000    4860.000000  4860.000000  4860.000000
# mean   2017.107613  12750.13107   21486.049588   121.147119    53.827798
# std       1.920456   5992.92231   17710.196964    58.003289    12.736042
# min    2000.000000   1200.00000       1.000000     0.000000     1.100000
# 25%    2016.000000   8000.00000    8339.250000   125.000000    44.800000
# 50%    2017.000000  11990.00000   17462.000000   145.000000    55.400000
# 75%    2019.000000  15733.75000   30967.000000   145.000000    60.100000
# max    2020.000000  92000.00000  138000.000000   555.000000   256.800000
#
#         engineSize
# count  4860.000000
# mean      1.457922
# std       0.400788
# min       0.000000
# 25%       1.200000
# 50%       1.600000
# 75%       1.700000
# max       2.900000

# %%
cat_features = df.select_dtypes(include=[np.object]).columns
df[cat_features].describe()
# Out:
#           model transmission fuelType
# count      4860         4860     4860
# unique       16            4        4
# top      Tucson       Manual   Petrol
# freq       1300         3611     2902

# %%
for i in cat_features:
    print(f' {i}:', df[i].unique())
    print()
# Out:
#  model: [' I20' ' Tucson' ' I10' ' IX35' ' I30' ' I40' ' Ioniq' ' Kona'
#  ' Veloster' ' I800' ' IX20' ' Santa Fe' ' Accent' ' Terracan' ' Getz'
#  ' Amica']
#
#  transmission: ['Manual' 'Automatic' 'Semi-Auto' 'Other']
#
#  fuelType: ['Petrol' 'Diesel' 'Hybrid' 'Other']

# %%
num_features = df.select_dtypes(exclude=[np.object]).columns
df[num_features]
# Out:
#       year  price  mileage  tax   mpg  engineSize
# 0     2017   7999    17307  145  58.9         1.2
# 1     2016  14499    25233  235  43.5         2.0
# 2     2016  11399    37877   30  61.7         1.7
# 3     2016   6499    23789   20  60.1         1.0
# 4     2015  10199    33177  160  51.4         2.0
# ...    ...    ...      ...  ...   ...         ...
# 4855  2016   8680    25906    0  78.4         1.6
# 4856  2015   7830    59508   30  65.7         1.7
# 4857  2017   6830    13810   20  60.1         1.0
# 4858  2018  13994    23313  145  44.8         1.6
# 4859  2016  15999    11472  125  57.6         1.7
#
# [4860 rows x 6 columns]

# %%
# Plot a heatmap to see correlation among numerical features
mask = np.zeros_like(df.corr()) 
mask[np.triu_indices_from(mask)]=True

plt.figure(figsize=(10, 7))
plt.title('Heatmap of Hyundai Dataset', size=16)
sns.heatmap(df.corr(method='spearman'), cmap='coolwarm', annot=True, mask=mask, vmax=1);

# %% [markdown]
# year dan mileage memiliki korelasi yang tinggi. Kemungkinan besar akan menyebabkan multicollinearity.

# %% [markdown]
# ## **EDA**

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 6))

for i, var in enumerate(cat_features):
    sns.countplot(y=var, data=df, ax=axes[i])
    axes[i].set_title(f'{var}', fontsize=15)

plt.show()

# %%
fig, axes = plt.subplots(6, 2, figsize=(20, 20))

for i, var in enumerate(num_features):
    sns.histplot(x=var, data=df, ax=axes[i, 0], kde=True)
    sns.boxplot(x=var, data=df, ax=axes[i, 1])

plt.tight_layout()
plt.show()

# %%
model_price = df.groupby('model')['price'].mean().sort_values()

plt.figure(figsize=(12, 6))
plt.title('Hyundai average price for each model')
pal = sns.color_palette('coolwarm', len(model_price))

sns.barplot(x=model_price.index, y=model_price.values, palette=pal)

plt.xlabel('Model')
plt.ylabel('Price (Euros)')
plt.tight_layout();

# %%
year_price = df.groupby('year')['price'].mean().sort_values()

plt.figure(figsize=(12, 6))
plt.title('Hyundai Average Price by Year')
pal = sns.color_palette('coolwarm', len(year_price))

sns.barplot(x=year_price.index, y=year_price.values, palette=pal)

plt.xlabel('Year')
plt.ylabel('Price (Euros)')
plt.tight_layout();

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x=df['mileage'], y=df['price']);

# %%
df[df['price'] > 40000]
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 1985   Santa Fe  2020  43995    Semi-Auto       10   Diesel  145  39.2
# 2693   Santa Fe  2019  40365    Semi-Auto        1   Diesel  145  39.2
# 4247        I10  2017  92000    Automatic    35460   Petrol  150  47.9
#
#       engineSize
# 1985         2.2
# 2693         2.2
# 4247         1.2

# %% [markdown]
# Harga I10 tahun 2017 ini rasanya kurang masuk di akal jika dibandingkan dengan harga model serupa yang berada di kisaran 7000an. Oleh karena itu, data ini dianggap sebagai outlier dan bisa di-drop saja.

# %%
df[df['model'].str.contains('Santa Fe')]
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 110    Santa Fe  2014  15500    Automatic    37006   Diesel  265  41.5
# 129    Santa Fe  2017  18999    Automatic    20599   Diesel  150  42.8
# 170    Santa Fe  2019  34998    Semi-Auto     4133   Diesel  145  39.2
# 171    Santa Fe  2019  34998    Semi-Auto     4956   Diesel  145  39.2
# 180    Santa Fe  2017  15998       Manual    48034   Diesel  205  47.1
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 4798   Santa Fe  2019  32995    Semi-Auto     3920   Diesel  145  39.2
# 4818   Santa Fe  2019  35995    Semi-Auto     6918   Diesel  145  39.2
# 4820   Santa Fe  2019  35985    Automatic      100   Diesel  145  39.2
# 4831   Santa Fe  2018  20985    Automatic    31123   Diesel  145  42.8
# 4854   Santa Fe  2019  29995    Semi-Auto     1567   Diesel  145  39.8
#
#       engineSize
# 110          2.2
# 129          2.2
# 170          2.2
# 171          2.2
# 180          2.2
# ...          ...
# 4798         2.2
# 4818         2.2
# 4820         2.2
# 4831         2.2
# 4854         2.2
#
# [245 rows x 9 columns]

# %%
df[df['model'].str.contains('I10')]
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 3      I10  2016   6499       Manual    23789   Petrol   20  60.1         1.0
# 5      I10  2015   6149       Manual    41650   Petrol   20  60.1         1.0
# 17     I10  2018   7100       Manual    35000   Petrol  145  60.1         1.0
# 18     I10  2016   7500       Manual     6000   Petrol   20  57.6         1.2
# 23     I10  2016   8100       Manual     7447   Petrol   30  57.6         1.2
# ...    ...   ...    ...          ...      ...      ...  ...   ...         ...
# 4849   I10  2018   7500       Manual    13457   Petrol  145  60.1         1.0
# 4850   I10  2018   7200       Manual    17879   Petrol  145  60.1         1.0
# 4851   I10  2018   7995       Manual     8851   Petrol  145  60.1         1.0
# 4852   I10  2018   7200       Manual    14788   Petrol  150  60.1         1.0
# 4857   I10  2017   6830       Manual    13810   Petrol   20  60.1         1.0
#
# [1092 rows x 9 columns]

# %%
df[df['tax'] > 300]
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 229        I800  2017  15985    Automatic    35154   Diesel  325  33.6
# 533        I800  2016  14998    Automatic    17110   Diesel  325  33.6
# 783        I800  2016  13710    Automatic    27802   Diesel  325  33.6
# 1721       I800  2017  15499    Automatic    18000   Diesel  330  33.6
# 2194       IX35  2013   8471    Automatic    49180   Diesel  305  39.2
# 2386       I800  2016  12711    Automatic    48039   Diesel  325  33.6
# 3553       I800  2016  13110    Automatic    53292   Diesel  330  33.6
# 3980       I800  2016  12000    Automatic    55088   Diesel  330  33.6
# 4062       I800  2016  14300    Automatic    51446   Diesel  325  33.6
# 4311   Terracan  2005   2895       Manual   130000   Diesel  325  32.8
# 4493       I800  2016  11995    Automatic    53000   Diesel  330  33.6
# 4552   Terracan  2003   3290       Manual    78000   Diesel  325  32.8
# 4665   Santa Fe  2009   4495       Manual    95000   Diesel  305  38.7
# 4705   Santa Fe  2002   1200       Manual    94000   Petrol  325  30.4
# 4751       I800  2017  14000    Automatic    23870   Diesel  325  33.6
# 4756   Santa Fe  2006   3490       Manual    71000   Petrol  555  28.8
#
#       engineSize
# 229          2.5
# 533          2.5
# 783          2.5
# 1721         2.5
# 2194         2.0
# 2386         2.5
# 3553         2.5
# 3980         2.5
# 4062         2.5
# 4311         2.9
# 4493         2.5
# 4552         2.9
# 4665         2.2
# 4705         2.4
# 4751         2.5
# 4756         2.4

# %% [markdown]
# Pajak mobil tua bisa saja menjadi lebih mahal karena dikenakan pajak progresif untuk mobil-mobil yang umurnya sudah lebih dari 10 tahun misalnya.

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x=df['mpg'], y=df['price']);

# %%
df[df['mpg'] > 250]
# Out:
#        model  year  price transmission  mileage fuelType  tax    mpg  \
# 1213   Ioniq  2018  18970    Automatic    14886   Hybrid  135  256.8
# 2088   Ioniq  2019  19995    Automatic     7386   Hybrid  135  256.8
# 2215   Ioniq  2018  18999    Automatic    12045   Hybrid  135  256.8
#
#       engineSize
# 1213         1.6
# 2088         1.6
# 2215         1.6

# %%
df[df['model'].str.contains('Ioniq')]
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 30     Ioniq  2018  15000    Automatic    32227   Hybrid  135  78.5
# 74     Ioniq  2019  19800    Automatic     1963   Petrol  135  78.5
# 199    Ioniq  2019  20998    Automatic     5530   Hybrid  140  62.8
# 210    Ioniq  2019  22998    Automatic     2844   Hybrid  140   1.1
# 255    Ioniq  2018  17298    Automatic    19348   Hybrid  135  78.5
# ...      ...   ...    ...          ...      ...      ...  ...   ...
# 4791   Ioniq  2018  15998    Automatic    19054   Hybrid  135  78.5
# 4795   Ioniq  2017  15995    Automatic    18436   Hybrid  135  78.5
# 4806   Ioniq  2020  28995    Automatic     5213   Hybrid  135   1.1
# 4807   Ioniq  2019  18995    Automatic     4500   Hybrid  135  78.5
# 4819   Ioniq  2020  22995    Automatic     3358   Hybrid  135  62.8
#
#       engineSize
# 30           1.6
# 74           1.6
# 199          1.6
# 210          1.6
# 255          1.6
# ...          ...
# 4791         1.6
# 4795         1.6
# 4806         1.6
# 4807         1.6
# 4819         1.6
#
# [284 rows x 9 columns]

# %% [markdown]
# **1 mpg = 0.425144 kml**

# %%
plt.figure(figsize=(14, 4))
df.groupby('fuelType')['mpg'].mean().plot.barh();

# %%
plt.figure(figsize=(14, 4))
df.groupby('transmission')['mpg'].mean().plot.barh();

# %%
df['transmission'].value_counts()
# Out:
# Manual       3611
# Automatic     669
# Semi-Auto     578
# Other           2
# Name: transmission, dtype: int64

# %%
df[df['transmission'].str.contains('Other')]
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 4739    Ioniq  2017  12495        Other    27779   Hybrid    0  78.5
# 4761   Tucson  2017  16995        Other    25915   Petrol  145  39.8
#
#       engineSize
# 4739         1.6
# 4761         1.6

# %%
df['fuelType'].value_counts()
# Out:
# Petrol    2902
# Diesel    1608
# Hybrid     349
# Other        1
# Name: fuelType, dtype: int64

# %%
df[df['fuelType'].str.contains('Other')]
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 4673   Ioniq  2017  12800    Automatic    54698    Other  140  78.5
#
#       engineSize
# 4673         1.6

# %%
engine_0 = df[df['engineSize'] == 0.0]
engine_0
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 31     Tucson  2015  15200    Automatic    28904   Diesel  200  46.3
# 32        I10  2014   7700    Automatic     8646   Petrol  160  45.6
# 33        I30  2017  10500    Automatic    17663   Diesel   20  72.4
# 34        I20  2017  11400    Automatic    12661   Petrol  145  44.1
# 37        I10  2018   9000       Manual     7126   Petrol  145  60.1
# 39        I10  2018   8500       Manual    12948   Petrol  145  60.1
# 40        I30  2019  14500       Manual     2481   Petrol  145  41.5
# 41     Tucson  2016  13800       Manual    27311   Diesel   30  61.7
# 42        I30  2016   9000       Manual    34443   Diesel    0  78.4
# 43     Tucson  2017  13800       Manual    16961   Diesel   30  61.7
# 45        I10  2013   5000       Manual    45230   Petrol   20  61.4
# 46        I10  2018  10300       Manual     6349   Petrol  145  57.6
# 47        I40  2015  11500       Manual    13268   Diesel   30  65.7
# 48        I30  2016   9000       Manual    29610   Diesel    0  78.4
# 49       IX35  2015  11400       Manual    23041   Diesel  165  51.4
# 50        I20  2017  10000       Manual    21821   Petrol  145  61.4
# 51        I10  2018   7800       Manual    17397   Petrol  150  60.1
# 52        I10  2016   6300       Manual    31854   Petrol   20  60.1
# 53     Tucson  2016  11300       Manual    37993   Diesel   30  61.7
# 54       I800  2018  15500       Manual    30305   Diesel  145  31.7
# 55        I20  2018  11700       Manual     3920   Petrol  150  46.3
# 61     Tucson  2017  15000       Manual    23310   Diesel   30  61.7
# 62     Tucson  2019  15000       Manual    22397   Petrol  150  34.9
# 63     Tucson  2019  16300       Manual    10066   Petrol  150  34.9
# 64        I10  2018   8300       Manual    13148   Petrol  150  60.1
# 65       I800  2019  18500       Manual     7691   Diesel  150  31.7
# 72        I10  2017   7300       Manual    15594   Petrol   20  60.1
# 73        I20  2015   7500       Manual    28123   Petrol   30  56.5
# 75        I10  2015   7500       Manual    13637   Petrol   30  57.6
# 76     Tucson  2017  15700    Automatic     7457   Diesel  125  57.6
# 77        I20  2017   8500       Manual    16708   Petrol  145  58.9
# 82        I10  2017   8000       Manual    16636   Petrol  145  60.1
# 83        I20  2017   8600       Manual    19398   Petrol   30  58.9
# 108       I10  2014   6600       Manual    31090   Petrol   30  57.6
# 119      IX35  2015   9700       Manual    26564   Petrol  200  41.5
# 120      IX35  2014   8700       Manual    54304   Diesel  145  53.3
# 121       I20  2016   7500       Manual    41496   Petrol   30  56.5
# 122      IX20  2014   6500       Manual    38601   Petrol  125  50.4
# 123       I10  2017   7000       Manual    31232   Petrol  145  57.7
# 4243   Tucson  2018  13000       Manual    37079   Petrol  145  44.8
# 4244      I10  2016   6300       Manual    17272   Petrol   20  61.4
# 4246      I10  2013   5000       Manual    28520   Petrol   20  61.4
# 4286   Tucson  2016  11500       Manual    52455   Diesel   30  61.7
# 4290     I800  2018  15500       Manual    31312   Diesel  145  31.7
# 4292      I10  2015   5300       Manual    47660   Petrol   20  60.1
# 4293      I10  2019   9400       Manual     4419   Petrol  145  60.1
# 4570      I20  2018   7698       Manual    30012   Petrol  145  55.4
#
#       engineSize
# 31           0.0
# 32           0.0
# 33           0.0
# 34           0.0
# 37           0.0
# 39           0.0
# 40           0.0
# 41           0.0
# 42           0.0
# 43           0.0
# 45           0.0
# 46           0.0
# 47           0.0
# 48           0.0
# 49           0.0
# 50           0.0
# 51           0.0
# 52           0.0
# 53           0.0
# 54           0.0
# 55           0.0
# 61           0.0
# 62           0.0
# 63           0.0
# 64           0.0
# 65           0.0
# 72           0.0
# 73           0.0
# 75           0.0
# 76           0.0
# 77           0.0
# 82           0.0
# 83           0.0
# 108          0.0
# 119          0.0
# 120          0.0
# 121          0.0
# 122          0.0
# 123          0.0
# 4243         0.0
# 4244         0.0
# 4246         0.0
# 4286         0.0
# 4290         0.0
# 4292         0.0
# 4293         0.0
# 4570         0.0

# %%
engine_0['model'].unique()
# Out:
# array([' Tucson', ' I10', ' I30', ' I20', ' I40', ' IX35', ' I800',
#        ' IX20'], dtype=object)

# %%
models = ['Tucson', 'I10', 'I30', 'I20', 'I40', 'IX35', 'I800', 'IX20']

for i in models:
    print(f'{i}:', df[df['model'].str.contains(i)]['engineSize'].mean())
# Out:
# Tucson: 1.6734615384615212
# I10: 1.0667582417582508
# I30: 1.4720149253731363
# I20: 1.1655241935483844
# I40: 1.6692913385826738
# IX35: 1.7279661016949137
# I800: 2.4358974358974357
# IX20: 1.4803921568627465

# %%
df.corr()['price']
# Out:
# year          0.575765
# price         1.000000
# mileage      -0.443576
# tax           0.321028
# mpg          -0.320355
# engineSize    0.522384
# Name: price, dtype: float64

# %% [markdown]
# ## **Preprocessing**

# %%
# Drop rows that contain outliers
df = df.drop([4247, 4673, 4739, 4761], axis=0)
df.reset_index()
# Out:
#       index    model  year  price transmission  mileage fuelType  tax   mpg  \
# 0         0      I20  2017   7999       Manual    17307   Petrol  145  58.9
# 1         1   Tucson  2016  14499    Automatic    25233   Diesel  235  43.5
# 2         2   Tucson  2016  11399       Manual    37877   Diesel   30  61.7
# 3         3      I10  2016   6499       Manual    23789   Petrol   20  60.1
# 4         4     IX35  2015  10199       Manual    33177   Diesel  160  51.4
# ...     ...      ...   ...    ...          ...      ...      ...  ...   ...
# 4851   4855      I30  2016   8680       Manual    25906   Diesel    0  78.4
# 4852   4856      I40  2015   7830       Manual    59508   Diesel   30  65.7
# 4853   4857      I10  2017   6830       Manual    13810   Petrol   20  60.1
# 4854   4858   Tucson  2018  13994       Manual    23313   Petrol  145  44.8
# 4855   4859   Tucson  2016  15999    Automatic    11472   Diesel  125  57.6
#
#       engineSize
# 0            1.2
# 1            2.0
# 2            1.7
# 3            1.0
# 4            2.0
# ...          ...
# 4851         1.6
# 4852         1.7
# 4853         1.0
# 4854         1.6
# 4855         1.7
#
# [4856 rows x 10 columns]

# %%
df.to_csv('hyundai_new.csv', index=False)

# %%
transformer = ColumnTransformer([
    ('One Hot', OneHotEncoder(drop='first'), ['transmission', 'fuelType']),
    ('Binary', ce.BinaryEncoder(), ['model'])
], remainder='passthrough')

# %% [markdown]
# ## **Data splitting**

# %%
# Define X and y
X = df.drop(['price'], axis=1)
y = df['price']

# %% [markdown]
# ### **Multicollinearity**

# %%
# Create a new variable for X, then fit and transform to calculate VIF
X_trans = pd.DataFrame(transformer.fit_transform(X))
X_trans.columns = transformer.get_feature_names()

# %%
# Function to calculate VIF
def calc_vif(x):
    vif = pd.DataFrame()
    vif['variables'] = x.columns
    vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
    vif['Acceptable'] = np.where(vif.VIF < 4, 'Yes', 'No') 
    return (vif)

# %%
X_trans.drop(['year', 'mpg', 'One Hot__x1_Hybrid', 'One Hot__x1_Petrol', 'engineSize'], axis=1, inplace=True)

# %%
calc_vif(X_trans)
# Out:
#                variables       VIF Acceptable
# 0     One Hot__x0_Manual  3.962492        Yes
# 1  One Hot__x0_Semi-Auto  1.518791        Yes
# 2        Binary__model_0  1.003430        Yes
# 3        Binary__model_1  1.517440        Yes
# 4        Binary__model_2  1.784641        Yes
# 5        Binary__model_3  2.825147        Yes
# 6        Binary__model_4  2.207080        Yes
# 7                mileage  2.521429        Yes
# 8                    tax  4.669882         No

# %% [markdown]
# ## **Assumptions check**

# %% [markdown]
# ### **Asumsi-asumsi yang harus dipenuhi:**
#
# 1. **Linear relationship:** Terdapat hubungan linear antara variabel independen (X) dan variabel dependen (y).
#
# 2. **Independence:** Residuals bersifat independen atau tidak memiliki korelasi dengan residual lainnya.
#
# 3. **Homoscedasticity:** Residuals memiliki variance yang konstan.
#
# 4. **Normality:** Residuals dari model terdistribusi dengan normal.

# %% [markdown]
# ### **Linear relationship**

# %%
x_col = 'price'
y_columns = ['year', 'mileage', 'tax', 'mpg', 'engineSize']

for y_col in y_columns:
    figure = plt.figure
    ax = plt.gca()
    ax.scatter(df[x_col], df[y_col])
    ax.set_xlabel(x_col)
    ax.set_ylabel(y_col)
    ax.set_title("{} vs {}".format(x_col, y_col))
    plt.show()

# %% [markdown]
# Tidak terdapat hubungan linear antara variabel independen dan target. Hal ini bisa diatasi dengan mentrasnformasi data terlebih dahulu ke dalam bentuk logaritmic misalnya.

# %% [markdown]
# ### **Normality**

# %% [markdown]
# **Create dummy variables**

# %%
df_dummy = pd.get_dummies(df, drop_first=True)
df_dummy.head()
# Out:
#    year  price  mileage  tax   mpg  engineSize  model_ Amica  model_ Getz  \
# 0  2017   7999    17307  145  58.9         1.2             0            0
# 1  2016  14499    25233  235  43.5         2.0             0            0
# 2  2016  11399    37877   30  61.7         1.7             0            0
# 3  2016   6499    23789   20  60.1         1.0             0            0
# 4  2015  10199    33177  160  51.4         2.0             0            0
#
#    model_ I10  model_ I20  ...  model_ Ioniq  model_ Kona  model_ Santa Fe  \
# 0           0           1  ...             0            0                0
# 1           0           0  ...             0            0                0
# 2           0           0  ...             0            0                0
# 3           1           0  ...             0            0                0
# 4           0           0  ...             0            0                0
#
#    model_ Terracan  model_ Tucson  model_ Veloster  transmission_Manual  \
# 0                0              0                0                    1
# 1                0              1                0                    0
# 2                0              1                0                    1
# 3                0              0                0                    1
# 4                0              0                0                    1
#
#    transmission_Semi-Auto  fuelType_Hybrid  fuelType_Petrol
# 0                       0                0                1
# 1                       0                0                0
# 2                       0                0                0
# 3                       0                0                1
# 4                       0                0                0
#
# [5 rows x 25 columns]

# %% [markdown]
# **Scaling data for linear model**

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_dummy)
df_scaled = pd.DataFrame(df_scaled, columns=df_dummy.columns)

# %% [markdown]
# **Create an OLS model**

# %%
fitur_dummy = df_scaled.columns.drop('price')

# %%
fitur = fitur_dummy
target = 'price' 
sm_lm = sm.OLS(df_scaled[target], sm.add_constant(df_scaled[fitur]))
result = sm_lm.fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.880
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     1483.
# Date:                Thu, 28 Oct 2021   Prob (F-statistic):               0.00
# Time:                        20:38:24   Log-Likelihood:                -1733.1
# No. Observations:                4856   AIC:                             3516.
# Df Residuals:                    4831   BIC:                             3678.
# Df Model:                          24
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   1.306e-14      0.005   2.63e-12      1.000      -0.010       0.010
# year                       0.3424      0.008     40.872      0.000       0.326       0.359
# mileage                   -0.2124      0.008    -27.655      0.000      -0.227      -0.197
# tax                       -0.1053      0.006    -16.336      0.000      -0.118      -0.093
# mpg                       -0.1971      0.010    -20.039      0.000      -0.216      -0.178
# engineSize                 0.1667      0.011     15.588      0.000       0.146       0.188
# model_ Amica              -0.0126      0.007     -1.790      0.074      -0.026       0.001
# model_ Getz               -0.0120      0.013     -0.906      0.365      -0.038       0.014
# model_ I10                -0.7419      0.148     -5.026      0.000      -1.031      -0.453
# model_ I20                -0.4868      0.107     -4.544      0.000      -0.697      -0.277
# model_ I30                -0.3698      0.111     -3.334      0.001      -0.587      -0.152
# model_ I40                -0.1941      0.057     -3.423      0.001      -0.305      -0.083
# model_ I800               -0.2073      0.055     -3.779      0.000      -0.315      -0.100
# model_ IX20               -0.3363      0.071     -4.742      0.000      -0.475      -0.197
# model_ IX35               -0.1652      0.055     -3.029      0.002      -0.272      -0.058
# model_ Ioniq              -0.3005      0.084     -3.592      0.000      -0.465      -0.137
# model_ Kona               -0.2530      0.089     -2.844      0.004      -0.427      -0.079
# model_ Santa Fe            0.0299      0.078      0.385      0.700      -0.123       0.182
# model_ Terracan           -0.0006      0.009     -0.069      0.945      -0.018       0.016
# model_ Tucson             -0.4180      0.157     -2.666      0.008      -0.725      -0.111
# model_ Veloster           -0.0283      0.010     -2.818      0.005      -0.048      -0.009
# transmission_Manual       -0.0976      0.009    -10.869      0.000      -0.115      -0.080
# transmission_Semi-Auto     0.0540      0.008      7.174      0.000       0.039       0.069
# fuelType_Hybrid            0.2119      0.012     18.387      0.000       0.189       0.234
# fuelType_Petrol           -0.0442      0.012     -3.786      0.000      -0.067      -0.021
# ==============================================================================
# Omnibus:                     1485.459   Durbin-Watson:                   1.754
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8225.471
# Skew:                           1.351   Prob(JB):                         0.00
# Kurtosis:                       8.775   Cond. No.                         119.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# **Plot residuals**

# %%
plt.figure(figsize=(7, 7))
sns.set_context('notebook', font_scale=1)
sns.distplot(result.resid)
plt.xlabel('Residuals', fontsize=16);

# %%
# Skewness check
result.resid.skew()
# Out:
# 1.3512670008764534

# %%
sm.qqplot(result.resid, line='45', fit=True);

# %% [markdown]
# Dilihat dari histogram dan QQ-plot, terlihat residual tidak mengikuti distribusi normal. Setelah divalidasi dengan cara melihat besaran nilai skewness-nya, ternyata memang benar residualnya skewed, yang mana nilai skewness-nya adalah 1.351 (termasuk highly skewed).

# %% [markdown]
# ### **Gauss-Markov (Independence, homoscedasticity)**

# %% [markdown]
# !['resid-plots.gif'](data:image/gif;base64,...)

# %%
# Gauss-Markov plot
plt.figure(figsize=(7, 7))
sns.set_context('notebook', font_scale=1)
sns.scatterplot(result.fittedvalues, result.resid)
sns.lineplot(result.fittedvalues, 0)
plt.xlabel('Fitted Values', fontsize=16)
plt.ylabel('Residual', fontsize=16);

# %% [markdown]
# Jika dicocokkan antara contoh-contoh residual Gauss-Markov dan hasil plot residual dari data yang dikerjakan, dapat dikatakan bahwa plot residual di atas menyerupai bentuk residual yang bias dan heteroscedastic. Dengan kata lain, residual berkorelasi dengan residual lainnya dan juga memiliki ragam yang heterogen.

# %% [markdown]
# ### **Interpretasi**
#
# Karena asumsi-asumsi model linear tidak terpenuhi, maka untuk pemodelan selanjutnya akan digunakan model-model regresi non-parametric.

# %% [markdown]
# ## **Non-parametric modeling**

# %% [markdown]
# ### **Train-test splitting**

# %%
X_train, X_test, y_train, y_test= train_test_split(
    X,
    y,  
    test_size = 0.2,
    random_state = 1)

# %%
X_train_prep = pd.DataFrame(transformer.fit_transform(X_train))
X_test_prep = pd.DataFrame(transformer.transform(X_test))

X_train_prep.columns = transformer.get_feature_names()
X_test_prep.columns = transformer.get_feature_names()

# %% [markdown]
# ### **Model benchmark**

# %%
# Define models
knn = KNeighborsRegressor()
dt = DecisionTreeRegressor(random_state=1)
rf = RandomForestRegressor(random_state=1)
xgb = XGBRegressor()

models = [knn, dt, rf, xgb]
score = []
nilai_mean = []
nilai_std = []

for i in models:
    crossval = KFold(n_splits=5)
    estimator = Pipeline([
    ('model', i)
])

    model_cv = cross_val_score(estimator, X_train_prep, y_train, cv=crossval, scoring='neg_root_mean_squared_error', error_score='raise')
    score.append(model_cv)
    nilai_mean.append(model_cv.mean())
    nilai_std.append(model_cv.std())

# %%
pd.DataFrame({
    'model':['knn', 'dt', 'rf', 'xgb'],
    'mean':nilai_mean,
    'std':nilai_std
})
# Out:
#   model         mean         std
# 0   knn -5156.576438  159.276286
# 1    dt -1596.153545   33.231063
# 2    rf -1254.727692   44.934718
# 3   xgb -1215.231092   36.554036

# %% [markdown]
# ## **Model Performance on Test Set**

# %%
models={
    'XGB': XGBRegressor(),
    'RandomForest': RandomForestRegressor(random_state=1)
}

score=[]

for i in models:
    models[i].fit(X_train_prep, y_train)
    y_pred=models[i].predict(X_test_prep)
    score.append([mean_squared_error(y_test, y_pred)])
    score_root = np.sqrt(score)

score_before_tuning = pd.DataFrame(score_root, columns=['RMSE'], index = models.keys())
score_before_tuning
# Out:
#                      RMSE
# XGB           1249.880828
# RandomForest  1389.031739

# %% [markdown]
# ## **Tuning the model benchmark**

# %%
xgb.get_params()
# Out:
# {'objective': 'reg:squarederror',
#  'base_score': None,
#  'booster': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'gamma': None,
#  'gpu_id': None,
#  'importance_type': 'gain',
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %%
# Hyperparameter space XGBRegressor
hyperparam_space_xgb = [
    {'reg__learning_rate':[0.2], 'reg__n_estimators':[50], 'reg__max_depth':[3, 4, 5]},
    {'reg__learning_rate':[0.1], 'reg__n_estimators':[100], 'reg__max_depth':[3, 4, 5]},
    {'reg__learning_rate':[0.05], 'reg__n_estimators':[500], 'reg__max_depth':[3, 4, 5]},
    {'reg__learning_rate':[0.01], 'reg__n_estimators':[1000], 'reg__max_depth':[3, 4, 5]},
    {'reg__learning_rate':[0.005], 'reg__n_estimators':[5000], 'reg__max_depth':[3, 4, 5]}
]

# %%
# Create the algorithm chains
estimator_xgb = Pipeline([('reg', xgb)])

# Cross validation
kf = KFold(n_splits = 5, shuffle=True, random_state=1)

# Hyperparameter tuning
grid_xgb = GridSearchCV(
    estimator_xgb, 
    param_grid = hyperparam_space_xgb, 
    cv = kf, 
    scoring = 'neg_root_mean_squared_error', 
    n_jobs = -1 
)

# %%
grid_xgb.fit(X_train_prep, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('reg',
#                                         XGBRegressor(base_score=None,
#                                                      booster=None,
#                                                      colsample_bylevel=None,
#                                                      colsample_bynode=None,
#                                                      colsample_bytree=None,
#                                                      gamma=None, gpu_id=None,
#                                                      importance_type='gain',
#                                                      interaction_constraints=None,
#                                                      learning_rate=None,
#                                                      max_delta_step=None,
#                                                      max_depth=None,
#                                                      min_child_weight=...
#                          {'reg__learning_rate': [0.1],
#                           'reg__max_depth': [3, 4, 5],
#                           'reg__n_estimators': [100]},
#                          {'reg__learning_rate': [0.05],
#                           'reg__max_depth': [3, 4, 5],
#                           'reg__n_estimators': [500]},
#                          {'reg__learning_rate': [0.01],
#                           'reg__max_depth': [3, 4, 5],
#                           'reg__n_estimators': [1000]},
#                          {'reg__learning_rate': [0.005],
#                           'reg__max_depth': [3, 4, 5],
#                           'reg__n_estimators': [5000]}],
#              scoring='neg_root_mean_squared_error')

# %%
print('XGBRegressor')
print('Best_score:', grid_xgb.best_score_)
print('Best_params:', grid_xgb.best_params_)
# Out:
# XGBRegressor
# Best_score: -1163.6977476137702
# Best_params: {'reg__learning_rate': 0.005, 'reg__max_depth': 5, 'reg__n_estimators': 5000}

# %% [markdown]
# ## **Use the best estimator to predict test set**

# %%
xgb_tuning = grid_xgb.best_estimator_
xgb_tuning.fit(X_train_prep, y_train)

y_pred_xgb_tuning = xgb_tuning.predict(X_test_prep)
mse_xgb_tuning = mean_squared_error(y_test, y_pred_xgb_tuning)
rmse_xgb = np.sqrt(mse_xgb_tuning)

# %%
score_list = [rmse_xgb]
models = ['XGB']
score_after_tuning = pd.DataFrame({
    'Model': models,
    'RMSE': score_list
})

# %% [markdown]
# ## **Comparison**

# %%
score_before_tuning
# Out:
#                      RMSE
# XGB           1249.880828
# RandomForest  1389.031739

# %%
score_after_tuning
# Out:
#   Model         RMSE
# 0   XGB  1175.945111

# %%
plt.figure(figsize=(14, 8))
plot = sns.scatterplot(x=y_test, y=y_pred_xgb_tuning).set(title='Actual Price vs. Prediction', 
                                               xlabel='Price', 
                                               ylabel='Predicted Price');

# %% [markdown]
# ### **Interpretasi**
#
# Dengan menggunakan model non-parametrik, dalam kasus ini XGBRegressor adalah yang paling optimal, kita bisa mendapatkan hasil yang cukup baik dengan nilai RMSE berkisar di 1175. Ini artinya, rata-rata prediksi model bisa meleset sekitar +- 1175 Euro. Tentu masih banyak cara yang dapat dilakukan untuk dapat mengimprovisasi output model agar dapat menghasilkan nilai error yang lebih kecil, seperti mengisi nilai engineSize yang 0.0, melakukan feature selection, menggunakan hyperparameter lain saat tuning, dll.

# %% [markdown]
# ## **Save model**

# %% [markdown]
# **Pickle**

# %%
# Save model
import pickle

estimator = Pipeline([('preprocess', transformer), ('model', XGBRegressor())])
estimator.fit(X_train, y_train)

pickle.dump(estimator, open('Final_Model_XGB.sav', 'wb'))

# %%
# Load model
filename = 'Final_Model_XGB.sav'
loaded_model = pickle.load(open(filename, 'rb'))

# %%
np.sqrt(mean_squared_error(y_test, loaded_model.predict(X_test)))
# Out:
# 1249.8808283758885

# %% [markdown]
# ## **Model training**

# %%
hyundai_train = df[:972]
hyundai_test = df[972:]

hyundai_train.to_csv('hyundai_train.csv', index=False)
hyundai_test.to_csv('hyundai_test.csv', index=False)

# %%
# Basic operations
import pandas as pd
import numpy as np

# ML model
from xgboost.sklearn import XGBRegressor

# Feature engineering
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
import category_encoders as ce

# Model evaluation
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score, KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Model
import pickle
import joblib

# Data
df = pd.read_csv('hyundai_new.csv')

# Preprocess
transformer = ColumnTransformer([
                                ('One Hot', OneHotEncoder(drop='first'), ['transmission', 'fuelType']),
                                ('Binary', ce.BinaryEncoder(), ['model'])
                                ], remainder='passthrough')

# Data splitting
X = df.drop(columns='price', axis=1)
y = df['price']

# Model selection
model = XGBRegressor()

estimator = Pipeline([
                      ('preprocess', transformer),
                      ('reg', model)
])

hyperparam_space = [
    {'reg__learning_rate':[0.2], 'reg__n_estimators':[50], 'reg__max_depth':[3, 4, 5]},
    {'reg__learning_rate':[0.1], 'reg__n_estimators':[100], 'reg__max_depth':[3, 4, 5]},
    {'reg__learning_rate':[0.05], 'reg__n_estimators':[500], 'reg__max_depth':[3, 4, 5]},
    {'reg__learning_rate':[0.01], 'reg__n_estimators':[1000], 'reg__max_depth':[3, 4, 5]},
    {'reg__learning_rate':[0.005], 'reg__n_estimators':[5000], 'reg__max_depth':[3, 4, 5]}
]

crossval = KFold(n_splits = 5, shuffle=True, random_state=1)

grid_search = GridSearchCV(
    estimator, 
    param_grid = hyperparam_space, 
    cv = crossval,
    scoring = 'neg_root_mean_squared_error', 
    n_jobs = -1
)

grid_search.fit(X, y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('One '
#                                                                          'Hot',
#                                                                          OneHotEncoder(drop='first'),
#                                                                          ['transmission',
#                                                                           'fuelType']),
#                                                                         ('Binary',
#                                                                          BinaryEncoder(),
#                                                                          ['model'])])),
#                                        ('reg',
#                                         XGBRegressor(base_score=None,
#                                                      booster=None,
#                                                      colsample_bylevel=None,
#                                                      colsample_b...
#                          {'reg__learning_rate': [0.1],
#                           'reg__max_depth': [3, 4, 5],
#                           'reg__n_estimators': [100]},
#                          {'reg__learning_rate': [0.05],
#                           'reg__max_depth': [3, 4, 5],
#                           'reg__n_estimators': [500]},
#                          {'reg__learning_rate': [0.01],
#                           'reg__max_depth': [3, 4, 5],
#                           'reg__n_estimators': [1000]},
#                          {'reg__learning_rate': [0.005],
#                           'reg__max_depth': [3, 4, 5],
#                           'reg__n_estimators': [5000]}],
#              scoring='neg_root_mean_squared_error')

# %%
# Model Pickling
grid_search.best_estimator_.fit(X, y)
filename = 'Model_XGB.sav'
pickle.dump(grid_search.best_estimator_, open(filename, 'wb'))

# Load dataset
df = pd.read_csv('hyundai_new.csv')

# Load model
filename = 'Model_XGB.sav'
loaded_model = pickle.load(open(filename, 'rb'))

# %% [markdown]
# ### **Predict an observation**

# %%
df_predict = pd.DataFrame({
    'model':[' Tucson'],
    'year':[2019],
    'transmission':['Automatic'],
    'mileage':[14000],
    'fuelType':['Petrol'],
    'tax':[150],
    'mpg':[37],
    'engineSize':[1.6]
})

print('predicted price:', loaded_model.predict(df_predict))
# Out:
# predicted price: [17869.318]

# %%
df[(df['model'] == ' Tucson') & (df['year'] == 2019)]
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 13     Tucson  2019  17750       Manual    10000   Petrol  150  34.9
# 36     Tucson  2019  18000       Manual     4353   Petrol  145  35.3
# 62     Tucson  2019  15000       Manual    22397   Petrol  150  34.9
# 63     Tucson  2019  16300       Manual    10066   Petrol  150  34.9
# 106    Tucson  2019  15600       Manual     8000   Petrol  150  34.9
# ...       ...   ...    ...          ...      ...      ...  ...   ...
# 4356   Tucson  2019  16999    Automatic    13797   Petrol  145  36.2
# 4386   Tucson  2019  15499       Manual     9841   Petrol  145  34.9
# 4733   Tucson  2019  17499    Automatic    10169   Petrol  150  36.2
# 4734   Tucson  2019  14999       Manual    11229   Petrol  150  34.9
# 4807   Tucson  2019  15498       Manual    17131   Petrol  145  34.9
#
#       engineSize
# 13           1.6
# 36           1.6
# 62           0.0
# 63           0.0
# 106          1.6
# ...          ...
# 4356         1.6
# 4386         1.6
# 4733         1.6
# 4734         1.6
# 4807         1.6
#
# [310 rows x 9 columns]
